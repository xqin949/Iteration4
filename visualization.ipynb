# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats,integrate
from sklearn.preprocessing import LabelEncoder
import copy
LE = LabelEncoder()

# %%
df = pd.read_csv('city_day.csv')

# %%
current_palette = sns.color_palette("hls",12)#Color
#sns.boxplot(data = remove_outlier,palette = current_palette)
sns.boxplot(data = df,palette = current_palette)#plot boxplot
#plt.show()

# %%
#heatmap
sns.heatmap(df.corr())
plt.show()
